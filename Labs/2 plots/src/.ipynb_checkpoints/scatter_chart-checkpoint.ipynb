# %% [markdown]
#    ## 散点图
#
#    **能够直观地来表示三通道数据的一种图表**

# %%
import matplotlib.pyplot as plt
N=5

#手动设定好原始数据
province=['Ontario','Quebec','BritishColumbia','Manitoba','NovaScoti']
size = [908.607,1356.547,922.509,552.329,651.036]
population = [12851821,7903001,4400057,1208268,4160000]
injuries = [625,752,629,1255,630] 

fig = plt.figure(figsize=(9,6)) 
fig.canvas.set_window_title('Bubble ShowCase')



#以size的数量作为x轴，以population的量作为y轴，以injuries数据集来画制散点的大小
#  matplotlib.pyplot.scatter(x, y, s=None, c=None, marker=None, cmap=None, 
# norm=None, vmin=None, vmax=None, alpha=None, linewidths=None, verts=None, edgecolors=None, hold=None, data=None, **kwargs) 



#将省份的名称标注到图轴上 

    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
#画出x轴的名称
plt.xlabel('Size(*1000km2)')

#画出y轴的名称
plt.ylabel('Population(ten million)')

#给plot命名一个title名称
plt.title('The Car Accidents Injuries Rate in 5 Canada Provinces')

plt.grid()
plt.xlim(min(size)-(max(size)-min(size))*0.05, max(size)+(max(size)-min(size))*0.05)#设定x轴的数值范围
plt.ylim(min(population)-(max(population)-min(population))*0.05, max(population)+(max(population)-min(population))*0.05)#设定y轴的数值范围
#ax.set_xlim(min(size)-(max(size)-min(size))*0.05, max(size)+(max(size)-min(size))*0.05)

#显示plot
plt.show()
